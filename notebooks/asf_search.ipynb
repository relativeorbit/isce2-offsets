# %%
import geopandas as gpd
import asf_search as asf

# %%
gfa = gpd.read_file('../shirase.geojson')

# %%
gfa.geometry.iloc[0].wkt
# Out:
# 'POLYGON ((38.64011496417339 -69.91495892837159, 38.095015106954406 -70.02784143946306, 39.3056438596154 -70.5135264611673, 40.12963201587755 -70.30311890133042, 38.64011496417339 -69.91495892837159))'

# %%
results = asf.geo_search(
    platform=[asf.PLATFORM.SENTINEL1],
    processingLevel=asf.PRODUCT_TYPE.BURST,
    intersectsWith=gfa.geometry.iloc[0].wkt,
    polarization=asf.POLARIZATION.HH,
    flightDirection=asf.FLIGHT_DIRECTION.ASCENDING,
    #absoluteOrbit=absoluteOrbit,
)
len(results)
# Out:
# 120

# %%
gf = gpd.GeoDataFrame.from_features(results.geojson(), crs='EPSG:4326')
gf.head(3)
# Out:
#                                             geometry  centerLat  centerLon  \
# 0  POLYGON ((37.89029 -70.05377, 38.23505 -70.201... -69.870408  38.980705
# 1  POLYGON ((38.19904 -70.18624, 38.54818 -70.333... -70.001018  39.293709
# 2  POLYGON ((38.51171 -70.31818, 38.86529 -70.464... -70.131083  39.610595
#
#                stopTime                                       fileID  \
# 0  2024-04-13T17:56:57Z  S1_313154_IW2_20240413T175653_HH_5F70-BURST
# 1  2024-04-13T17:56:55Z  S1_313153_IW2_20240413T175651_HH_5F70-BURST
# 2  2024-04-13T17:56:52Z  S1_313152_IW2_20240413T175648_HH_5F70-BURST
#
#   flightDirection  pathNumber processingLevel  \
# 0       ASCENDING         146           BURST
# 1       ASCENDING         146           BURST
# 2       ASCENDING         146           BURST
#
#                                                  url             startTime  \
# 0  https://sentinel1-burst.asf.alaska.edu/S1A_IW_...  2024-04-13T17:56:54Z
# 1  https://sentinel1-burst.asf.alaska.edu/S1A_IW_...  2024-04-13T17:56:52Z
# 2  https://sentinel1-burst.asf.alaska.edu/S1A_IW_...  2024-04-13T17:56:49Z
#
#    ...  orbit polarization processingDate sensor  \
# 0  ...  53418           HH           None  C-SAR
# 1  ...  53418           HH           None  C-SAR
# 2  ...  53418           HH           None  C-SAR
#
#                          groupID pgeVersion  \
# 0  S1A_IWSH_0936_0942_053418_146     003.71
# 1  S1A_IWSH_0936_0942_053418_146     003.71
# 2  S1A_IWSH_0936_0942_053418_146     003.71
#
#                                            fileName  beamModeType  \
# 0  S1_313154_IW2_20240413T175653_HH_5F70-BURST.tiff            IW
# 1  S1_313153_IW2_20240413T175651_HH_5F70-BURST.tiff            IW
# 2  S1_313152_IW2_20240413T175648_HH_5F70-BURST.tiff            IW
#
#                                                burst  \
# 0  {'absoluteBurstID': 114737567, 'relativeBurstI...
# 1  {'absoluteBurstID': 114737566, 'relativeBurstI...
# 2  {'absoluteBurstID': 114737565, 'relativeBurstI...
#
#                                       additionalUrls
# 0  [https://sentinel1-burst.asf.alaska.edu/S1A_IW...
# 1  [https://sentinel1-burst.asf.alaska.edu/S1A_IW...
# 2  [https://sentinel1-burst.asf.alaska.edu/S1A_IW...
#
# [3 rows x 27 columns]

# %%
m = gf.explore(style_kwds=dict(color='magenta',fill=None))
gfa.explore(m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8d383788fac70ea7b7e09974264233b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8d383788fac70ea7b7e09974264233b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8d383788fac70ea7b7e09974264233b = L.map(
#                 &quot;map_c8d383788fac70ea7b7e09974264233b&quot;,
#                 {
#                     center: [-70.13159350000001, 39.6201355],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c8d383788fac70ea7b7e09974264233b);
#
#
#
#
#
#             var tile_layer_2abf4d93a326fec18d3ff3edad078aa4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2abf4d93a326fec18d3ff3edad078aa4.addTo(map_c8d383788fac70ea7b7e09974264233b);
#
#
#             map_c8d383788fac70ea7b7e09974264233b.fitBounds(
#                 [[-70.72583, 37.89029], [-69.537357, 41.349981]],
#                 {}
#             );
#
#
#         function geo_json_4dc3f6090fc48e85dad8b696554cca34_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;magenta&quot;, &quot;fill&quot;: null, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4dc3f6090fc48e85dad8b696554cca34_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4dc3f6090fc48e85dad8b696554cca34_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_4dc3f6090fc48e85dad8b696554cca34_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4dc3f6090fc48e85dad8b696554cca34_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_4dc3f6090fc48e85dad8b696554cca34.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4dc3f6090fc48e85dad8b696554cca34_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4dc3f6090fc48e85dad8b696554cca34 = L.geoJson(null, {
#                 onEachFeature: geo_json_4dc3f6090fc48e85dad8b696554cca34_onEachFeature,
#
#                 style: geo_json_4dc3f6090fc48e85dad8b696554cca34_styler,
#                 pointToLayer: geo_json_4dc3f6090fc48e85dad8b696554cca34_pointToLayer,
#         });
#
#         function geo_json_4dc3f6090fc48e85dad8b696554cca34_add (data) {
#             geo_json_4dc3f6090fc48e85dad8b696554cca34
#                 .addData(data);
#         }
#             geo_json_4dc3f6090fc48e85dad8b696554cca34_add({&quot;bbox&quot;: [37.89029, -70.72583, 41.349981, -69.537357], &quot;features&quot;: [{&quot;bbox&quot;: [37.89029, -70.201547, 40.063031, -69.537357], &quot;geometry&quot;: {&quot;coordinates&quot;: [

# %%
gf.iloc[0]
# Out:
# geometry           POLYGON ((37.89029 -70.053769, 38.235052 -70.2...
# centerLat                                                 -69.870408
# centerLon                                                  38.980705
# stopTime                                        2024-04-13T17:56:57Z
# fileID                   S1_313154_IW2_20240413T175653_HH_5F70-BURST
# flightDirection                                            ASCENDING
# pathNumber                                                       146
# processingLevel                                                BURST
# url                https://sentinel1-burst.asf.alaska.edu/S1A_IW_...
# startTime                                       2024-04-13T17:56:54Z
# sceneName                S1_313154_IW2_20240413T175653_HH_5F70-BURST
# browse                                                          None
# platform                                                 SENTINEL-1A
# bytes                                                      144353112
# md5sum                                                          None
# frameNumber                                                     None
# granuleType                                                     None
# orbit                                                          53418
# polarization                                                      HH
# processingDate                                                  None
# sensor                                                         C-SAR
# groupID                                S1A_IWSH_0936_0942_053418_146
# pgeVersion                                                    003.71
# fileName            S1_313154_IW2_20240413T175653_HH_5F70-BURST.tiff
# beamModeType                                                      IW
# burst              {'absoluteBurstID': 114737567, 'relativeBurstI...
# additionalUrls     [https://sentinel1-burst.asf.alaska.edu/S1A_IW...
# Name: 0, dtype: object

# %%
gf.burst.iloc[0]
# Out:
# {'absoluteBurstID': 114737567,
#  'relativeBurstID': 313154,
#  'fullBurstID': '146_313154_IW2',
#  'burstIndex': 6,
#  'samplesPerBurst': 23963,
#  'subswath': 'IW2',
#  'azimuthTime': '2024-04-13T17:56:53Z',
#  'azimuthAnxTime': '4700.7411688822'}

# %%
gf['burstID'] = gf.burst.str['fullBurstID']

# %%
gf.burstID.value_counts()
# Out:
# burstID
# 146_313154_IW2    24
# 146_313153_IW2    24
# 146_313152_IW2    24
# 146_313151_IW2    24
# 146_313150_IW2    24
# Name: count, dtype: int64

# %%
# Just use first burst
gf = gf[gf.burstID == gf.burstID.iloc[0]]
len(gf)
# Out:
# 24

# %%
cols = ['startTime','orbit']
gf.loc[:,cols]
# Out:
#                 startTime  orbit
# 0    2024-04-13T17:56:54Z  53418
# 5    2024-04-01T17:56:55Z  53243
# 10   2024-03-20T17:56:55Z  53068
# 15   2024-03-08T17:56:54Z  52893
# 20   2024-02-25T17:56:54Z  52718
# 25   2024-02-13T17:56:54Z  52543
# 30   2024-02-01T17:56:55Z  52368
# 35   2024-01-20T17:56:55Z  52193
# 40   2023-12-27T17:56:56Z  51843
# 45   2023-12-15T17:56:57Z  51668
# 50   2023-12-03T17:56:58Z  51493
# 55   2023-11-21T17:56:58Z  51318
# 60   2023-11-09T17:56:58Z  51143
# 65   2023-10-16T17:56:59Z  50793
# 70   2023-10-04T17:56:58Z  50618
# 75   2023-09-22T17:56:59Z  50443
# 80   2023-09-10T17:56:58Z  50268
# 85   2023-08-29T17:56:58Z  50093
# 90   2023-08-17T17:56:57Z  49918
# 95   2023-08-05T17:56:57Z  49743
# 100  2023-07-24T17:56:56Z  49568
# 105  2023-07-12T17:56:55Z  49393
# 110  2023-06-30T17:56:54Z  49218
# 115  2023-06-18T17:56:53Z  49043

# %%
gf['datetime'] = gpd.pd.to_datetime(gf.startTime)
gf = gf.sort_values(by='datetime', ignore_index=True)
gf.datetime.diff().dt.days
# Out:
# 0      NaN
# 1     12.0
# 2     12.0
# 3     12.0
# 4     12.0
# 5     12.0
# 6     12.0
# 7     12.0
# 8     12.0
# 9     11.0
# 10    12.0
# 11    23.0
# 12    12.0
# 13    12.0
# 14    11.0
# 15    11.0
# 16    23.0
# 17    12.0
# 18    11.0
# 19    12.0
# 20    12.0
# 21    12.0
# 22    12.0
# 23    11.0
# Name: datetime, dtype: float64

# %%
gf.datetime.head(3)
# Out:
# 0   2023-06-18 17:56:53+00:00
# 1   2023-06-30 17:56:54+00:00
# 2   2023-07-12 17:56:55+00:00
# Name: datetime, dtype: datetime64[ns, UTC]

# %%
# fairly consistent 12 day repeat cycle, so pick every other for reference and secondary
for i in range(len(gf)-2):
    print(gf.datetime.dt.date.iloc[i], gf.datetime.dt.date.iloc[i+2])
    print(gf.orbit.iloc[i], gf.orbit.iloc[i+2])
# Out:
# 2023-06-18 2023-07-12
# 49043 49393
# 2023-06-30 2023-07-24
# 49218 49568
# 2023-07-12 2023-08-05
# 49393 49743
# 2023-07-24 2023-08-17
# 49568 49918
# 2023-08-05 2023-08-29
# 49743 50093
# 2023-08-17 2023-09-10
# 49918 50268
# 2023-08-29 2023-09-22
# 50093 50443
# 2023-09-10 2023-10-04
# 50268 50618
# 2023-09-22 2023-10-16
# 50443 50793
# 2023-10-04 2023-11-09
# 50618 51143
# 2023-10-16 2023-11-21
# 50793 51318
# 2023-11-09 2023-12-03
# 51143 51493
# 2023-11-21 2023-12-15
# 51318 51668
# 2023-12-03 2023-12-27
# 51493 51843
# 2023-12-15 2024-01-20
# 51668 52193
# 2023-12-27 2024-02-01
# 51843 52368
# 2024-01-20 2024-02-13
# 52193 52543
# 2024-02-01 2024-02-25
# 52368 52718
# 2024-02-13 2024-03-08
# 52543 52893
# 2024-02-25 2024-03-20
# 52718 53068
# 2024-03-08 2024-04-01
# 52893 53243
# 2024-03-20 2024-04-13
# 53068 53418
